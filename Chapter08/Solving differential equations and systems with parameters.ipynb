# %%
from scipy.integrate import ode

y0, t0 = [1.0j, 2.0], 0

def f(t, y, arg1):
    return [1j*arg1*y[0] + y[1], -arg1*y[1]**2]
def jac(t, y, arg1):
    return [[1j*arg1, 1], [0, -arg1*2*y[1]]]

# %%
import numpy
from numpy import linspace
import scipy
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
sigma=10.0
b=8/3.0
r=28.0
f = lambda x,t: [sigma*(x[1]-x[0]), r*x[0]-x[1]-x[0]*x[2], x[0]*x[1]-b*x[2]]

# %%
tmax, n = 100, 10000
init = [0, 1, 1.05]
t = numpy.linspace(0, tmax, n)
Z = odeint(f,init, t)
xs,ys,zs = Z.T

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
s = 10
for i in range(0,n-s,s):
    ax.plot(xs[i:i+s+1], ys[i:i+s+1], zs[i:i+s+1])
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)
plt.subplot(121); plt.plot(t[1:2000],zs[1:2000])
plt.subplot(122); plt.plot(ys[1:2000],zs[1:2000])
plt.show()
